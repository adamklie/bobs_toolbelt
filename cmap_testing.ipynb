# %% [markdown]
# # Matplotlib Colormap Testing

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Autoreload extension
if 'autoreload' not in get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    
# %autoreload 2

import custom_cmaps

# %% [markdown]
# ## Testing loading of cpt cmap

# %%
cmap_cpt = custom_cmaps.get_cmap('deep', file_type='cpt')

# %%
type(cmap_cpt)
# Out:
# matplotlib.colors.LinearSegmentedColormap

# %% [markdown]
# ## Testing loading of csv cmap

# %%
cmap_csv = custom_cmaps.get_cmap('SobRock', file_type='csv', cmap_type='ListedColormap')

# %%
type(cmap_csv)
# Out:
# matplotlib.colors.ListedColormap

# %% [markdown]
# ## Testing saving cmaps to cpt

# %%
custom_cmaps.save_cmap_to_cpt(cmap_csv, N=5, filename='./matplotlib_cmaps/SobRock.cpt')

# %% [markdown]
# ## Displaying all 3

# %%
cmap_cpt2 = custom_cmaps.get_cmap('SobRock', file_type='cpt')

# %%
custom_cmaps.plot_examples([cmap_cpt, cmap_cpt2, cmap_csv])

# %%
iris_df = sns.load_dataset('iris')

# %%
iris_df['species'].value_counts().plot(kind='bar', color=cmap_cpt(np.linspace(0, 1, 3)));

# %% [markdown]
# ## Create my own from scratch

# %%
cmap = LinearSegmentedColormap.from_list(name='test', colors=['#FC766AFF', '#5B84B1FF'])

# %%
cmap = custom_cmaps.get_cmap('coral_coast_div', file_type='cpt')

# %%
custom_cmaps.save_cmap_to_cpt(cmap, filename='matplotlib_cmaps/coral_coast_div.cpt')

# %% [markdown]
# # custom_cmaps.plot_examples([cmap])
